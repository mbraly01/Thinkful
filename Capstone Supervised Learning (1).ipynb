# %% [markdown]
# Research Question: Can a winner of a fight be predicted based on the types of attacks made?

# %%
import sys
import seaborn as sns
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn import tree
import graphviz
import pydotplus
from IPython.display import Image
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.metrics import roc_curve, roc_auc_score
import os

# %% [markdown]
# There are two corners that fighters can be in: Red or Blue. The types of attacks performed by each fighter were categorized by these two corners. I created a dummy feature to find out when the Red corner won. I deleted all other features and would bring them back to test out which values created the best results. I ultimately decided on including all of the different attack types for the Red corner because this was what I was most interested in exploring.

# %%
df = pd.read_csv('data.csv')

df.columns = df.columns.str.replace(' ', '')
df['Winner'] = df['Winner'].map({'Red': 1, 'Blue': 0, 'Draw': None})

df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# I've decided to see which values are most highly correlated to eachother to remove, as well as to explore all the data's relation to the Winner column.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
print (df.corr())
# Out:
#                                 Winner  title_bout  no_of_rounds  \
# Winner                        1.000000  0.078572    0.030635
# title_bout                    0.078572  1.000000    0.720779
# no_of_rounds                  0.030635  0.720779    1.000000
# B_current_lose_streak         0.001681 -0.135037   -0.128996
# B_current_win_streak         -0.025609  0.325688    0.324650
# B_draw                       NaN       NaN         NaN
# B_avg_BODY_att               -0.115562  0.020875    0.039672
# B_avg_BODY_landed            -0.101472  0.031579    0.048708
# B_avg_CLINCH_att             -0.035410  0.018988    0.011374
# B_avg_CLINCH_landed          -0.034547  0.021995    0.015205
# B_avg_DISTANCE_att           -0.120555  0.013246    0.041598
# B_avg_DISTANCE_landed        -0.116754  0.026187    0.067010
# B_avg_GROUND_att             -0.008356  0.096426    0.077862
# B_avg_GROUND_landed          -0.013310  0.097127    0.078676
# B_avg_HEAD_att               -0.115486  0.035958    0.054911
# B_avg_HEAD_landed            -0.107671  0.068244    0.091917
# B_avg_KD                      0.000653  0.087571    0.131297
# B_avg_LEG_att                -0.053606  0.012652    0.034904
# B_avg_LEG_landed             -0.047440  0.009158    0.034507
# B_avg_PASS                   -0.008736  0.053944    0.031593
# B_avg_REV                     0.019113 -0.046538   -0.058060
# B_avg_SIG_STR_att            -0.121801  0.034887    0.056685
# B_avg_SIG_STR_landed         -0.115516  0.058991    0.086704
# B_avg_SIG_STR_pct             0.022660  0.091668    0.095428
# B_avg_SUB_ATT                 0.044279 -0.011897   -0.035029
# B_avg_TD_att                 -0.055103  0.019176   -0.003407
# B_avg_TD_landed              -0.035490  0.063511    0.031786
# B_avg_TD_pct                  0.016022  0.070342    0.038257
# B_avg_TOTAL_STR_att          -0.089351  0.050513    0.053033
# B_avg_TOTAL_STR_landed       -0.044995  0.074626    0.066064
# B_longest_win_streak          0.013307  0.300984    0.376410
# B_losses                      0.016731 -0.035737    0.045822
# B_avg_opp_BODY_att           -0.073301 -0.044217   -0.012800
# B_avg_opp_BODY_landed        -0.040635 -0.048035   -0.017015
# B_avg_opp_CLINCH_att          0.015639 -0.025399   -0.022324
# B_avg_opp_CLINCH_landed       0.012710 -0.029690   -0.024066
# B_avg_opp_DISTANCE_att       -0.093046 -0.024546    0.005371
# B_avg_opp_DISTANCE_landed    -0.080341 -0.047548   -0.014035
# B_avg_opp_GROUND_att          0.068772 -0.070916   -0.081293
# B_avg_opp_GROUND_landed       0.061928 -0.070773   -0.075539
# B_avg_opp_HEAD_att           -0.064230 -0.037990   -0.013966
# B_avg_opp_HEAD_landed        -0.028549 -0.072957   -0.049547
# B_avg_opp_KD                  0.033991 -0.051269   -0.037257
# B_avg_opp_LEG_att            -0.067122 -0.020905   -0.003336
# B_avg_opp_LEG_landed         -0.060759 -0.031697   -0.014748
# B_avg_opp_PASS                0.023960 -0.088788   -0.096158
# B_avg_opp_REV                 0.031862 -0.011029   -0.040005
# B_avg_opp_SIG_STR_att        -0.073028 -0.040925   -0.013951
# B_avg_opp_SIG_STR_landed     -0.045967 -0.071914   -0.043010
# B_avg_opp_SIG_STR_pct         0.054802 -0.068013   -0.085242
# B_avg_opp_SUB_ATT             0.045771 -0.012977   -0.044600
# B_avg_opp_TD_att             -0.054438 -0.045057   -0.037094
# B_avg_opp_TD_landed          -0.004730 -0.085448   -0.089384
# B_avg_opp_TD_pct              0.062578 -0.086606   -0.100377
# B_avg_opp_TOTAL_STR_att      -0.045339 -0.049898   -0.039187
# B_avg_opp_TOTAL_STR_landed    0.009323 -0.065952   -0.069709
# B_total_rounds_fought         0.001667  0.151290    0.249112
# B_total_time_fought(seconds) -0.071784  0.021948    0.029189
# B_total_title_bouts           0.080543  0.298861    0.292902
# B_win_by_Decision_Majority    0.034002  0.079237    0.080146
# B_win_by_Decision_Split       0.014654  0.020173    0.049367
# B_win_by_Decision_Unanimous  -0.041985  0.157967    0.227287
# B_win_by_KO/TKO               0.026934  0.222239    0.323686
# B_win_by_Submission           0.022773  0.075911    0.114833
# B_win_by_TKO_Doctor_Stoppage  0.053340  0.109230    0.116945
# B_wins                        0.013366  0.226499    0.329168
# B_Height_cms                  0.006457 -0.013880    0.038980
# B_Reach_cms                  -0.017609 -0.004534    0.059195
# B_Weight_lbs                  0.022335  0.047080    0.112867
# R_current_lose_streak        -0.064775 -0.160570   -0.148378
# R_current_win_streak          0.062586  0.473789    0.394700
# R_draw                       NaN       NaN         NaN
# R_avg_BODY_att               -0.069068  0.089115    0.096554
# R_avg_BODY_landed            -0.046182  0.124796    0.122800
# R_avg_CLINCH_att              0.000605  0.103571    0.082456
# R_avg_CLINCH_landed           0.002882  0.122590    0.094303
# R_avg_DISTANCE_att           -0.094718  0.052314    0.081199
# R_avg_DISTANCE_landed        -0.076848  0.087432    0.123633
# R_avg_GROUND_att              0.100624  0.148075    0.127831
# R_avg_GROUND_landed           0.086439  0.160737    0.138032
# R_avg_HEAD_att               -0.064573  0.086673    0.107697
# R_avg_HEAD_landed            -0.020577  0.158609    0.177933
# R_avg_KD                      0.011820  0.101650    0.133935
# R_avg_LEG_att                -0.040124  0.093941    0.105807
# R_avg_LEG_landed             -0.039069  0.090867    0.103753
# R_avg_PASS                    0.083346  0.064023    0.023711
# R_avg_REV                    -0.018350 -0.060715   -0.080861
# R_avg_SIG_STR_att            -0.069834  0.098875    0.118877
# R_avg_SIG_STR_landed         -0.037480  0.167206    0.183182
# R_avg_SIG_STR_pct             0.074267  0.166388    0.148630
# R_avg_SUB_ATT                 0.060845 -0.015483   -0.049638
# R_avg_TD_att                  0.036355  0.041718    0.008663
# R_avg_TD_landed               0.082587  0.113645    0.064830
# R_avg_TD_pct                  0.094705  0.099865    0.057447
# R_avg_TOTAL_STR_att          -0.052049  0.114423    0.112856
# R_avg_TOTAL_STR_landed       -0.004318  0.161872    0.139191
# R_longest_win_streak          0.013012  0.324569    0.392725
# R_losses                     -0.135841 -0.113088   -0.004314
# R_avg_opp_BODY_att           -0.086642  0.026909    0.032887
# R_avg_opp_BODY_landed        -0.089988  0.005215    0.009111
# R_avg_opp_CLINCH_att         -0.038136  0.003482   -0.013750
# R_avg_opp_CLINCH_landed      -0.043117 -0.007767   -0.025541
# R_avg_opp_DISTANCE_att       -0.106465  0.014256    0.043426
# R_avg_opp_DISTANCE_landed    -0.125264 -0.033072    0.006151
# R_avg_opp_GROUND_att         -0.046579 -0.101239   -0.098293
# R_avg_opp_GROUND_landed      -0.066833 -0.111167   -0.099988
# R_avg_opp_HEAD_att           -0.115424 -0.012975    0.014679
# R_avg_opp_HEAD_landed        -0.142445 -0.090315   -0.050317
# R_avg_opp_KD                 -0.065158 -0.099872   -0.063499
# R_avg_opp_LEG_att            -0.063766  0.016913    0.033857
# R_avg_opp_LEG_landed         -0.073398 -0.006465    0.009266
# R_avg_opp_PASS               -0.050770 -0.107940   -0.118552
# R_avg_opp_REV                 0.007216 -0.051112   -0.076217
# R_avg_opp_SIG_STR_att        -0.116095 -0.004511    0.021301
# R_avg_opp_SIG_STR_landed     -0.141129 -0.063817   -0.030838
# R_avg_opp_SIG_STR_pct        -0.069665 -0.125160   -0.115717
# R_avg_opp_SUB_ATT             0.022890 -0.064366   -0.080344
# R_avg_opp_TD_att             -0.023120  0.031770    0.019631
# R_avg_opp_TD_landed          -0.041783 -0.079697   -0.078778
# R_avg_opp_TD_pct             -0.042394 -0.126058   -0.131707
# R_avg_opp_TOTAL_STR_att      -0.115422 -0.012515   -0.002933
# R_avg_opp_TOTAL_STR_landed   -0.107924 -0.055537   -0.057588
# R_total_rounds_fought        -0.088002  0.137494    0.255378
# R_total_time_fought(seconds) -0.048066  0.099776    0.091210
# R_total_title_bouts           0.044988  0.436133    0.415146
# R_win_by_Decision_Majority   -0.001037  0.043478    0.045257
# R_win_by_Decision_Split      -0.110986  0.006957    0.033610
# R_win_by_Decision_Unanimous  -0.031806  0.158009    0.245310
# R_win_by_KO/TKO              -0.020803  0.209194    0.335251
# R_win_by_Submission           0.002597  0.066054    0.093491
# R_win_by_TKO_Doctor_Stoppage -0.001264  0.035860    0.024305
# R_wins                       -0.043618  0.211212    0.329862
# R_Height_cms                  0.030625 -0.002304    0.065462
# R_Reach_cms                   0.050032  0.033029    0.088546
# R_Weight_lbs                  0.040932  0.053133    0.122449
# B_age                         0.082052  0.063266    0.139494
# R_age                        -0.151100  0.014772    0.097148
#
#                               B_current_lose_streak  B_current_win_streak  \
# Winner                        0.001681              -0.025609
# title_bout                   -0.135037               0.325688
# no_of_rounds                 -0.128996               0.324650
# B_current_lose_streak         1.000000              -0.571993
# B_current_win_streak         -0.571993               1.000000
# B_draw                       NaN                    NaN
# B_avg_BODY_att               -0.029255               0.025614
# B_avg_BODY_landed            -0.050964               0.034810
# B_avg_CLINCH_att             -0.046607               0.012627
# B_avg_CLINCH_landed          -0.054079               0.016582
# B_avg_DISTANCE_att            0.004314               0.014331
# B_avg_DISTANCE_landed        -0.031311               0.041153
# B_avg_GROUND_att             -0.175642               0.215001
# B_avg_GROUND_landed          -0.176252               0.216189
# B_avg_HEAD_att               -0.036391               0.060183
# B_avg_HEAD_landed            -0.105857               0.125524
# B_avg_KD                     -0.128921               0.177354
# B_avg_LEG_att                -0.028388               0.031109
# B_avg_LEG_landed             -0.034776               0.035763
# B_avg_PASS                   -0.172230               0.169774
# B_avg_REV                     0.007181              -0.042196
# B_avg_SIG_STR_att            -0.038772               0.058211
# B_avg_SIG_STR_landed         -0.097201               0.106854
# B_avg_SIG_STR_pct            -0.151011               0.148427
# B_avg_SUB_ATT                -0.063430               0.038499
# B_avg_TD_att                 -0.069151               0.081336
# B_avg_TD_landed              -0.131824               0.155938
# B_avg_TD_pct                 -0.132872               0.130282
# B_avg_TOTAL_STR_att          -0.057753               0.073635
# B_avg_TOTAL_STR_landed       -0.098122               0.105330
# B_longest_win_streak         -0.147460               0.472237
# B_losses                      0.341554              -0.208187
# B_avg_opp_BODY_att            0.055760              -0.088453
# B_avg_opp_BODY_landed         0.081334              -0.121306
# B_avg_opp_CLINCH_att          0.068501              -0.105978
# B_avg_opp_CLINCH_landed       0.076533              -0.118699
# B_avg_opp_DISTANCE_att        0.046250              -0.040721
# B_avg_opp_DISTANCE_landed     0.087955              -0.083234
# B_avg_opp_GROUND_att          0.194212              -0.212424
# B_avg_opp_GROUND_landed       0.191940              -0.211360
# B_avg_opp_HEAD_att            0.093854              -0.091177
# B_avg_opp_HEAD_landed         0.174404              -0.175640
# B_avg_opp_KD                  0.170238              -0.149489
# B_avg_opp_LEG_att             0.045035              -0.053270
# B_avg_opp_LEG_landed          0.057808              -0.065528
# B_avg_opp_PASS                0.151799              -0.189593
# B_avg_opp_REV                 0.012452              -0.012020
# B_avg_opp_SIG_STR_att         0.091933              -0.095866
# B_avg_opp_SIG_STR_landed      0.158552              -0.171953
# B_avg_opp_SIG_STR_pct         0.164631              -0.203103
# B_avg_opp_SUB_ATT             0.070689              -0.075640
# B_avg_opp_TD_att              0.075822              -0.077633
# B_avg_opp_TD_landed           0.149023              -0.179193
# B_avg_opp_TD_pct              0.142611              -0.189058
# B_avg_opp_TOTAL_STR_att       0.133155              -0.149326
# B_avg_opp_TOTAL_STR_landed    0.189795              -0.218781
# B_total_rounds_fought         0.070391               0.123225
# B_total_time_fought(seconds)  0.033936              -0.029306
# B_total_title_bouts           0.047779               0.063730
# B_win_by_Decision_Majority   -0.040414               0.060726
# B_win_by_Decision_Split      -0.001928               0.085224
# B_win_by_Decision_Unanimous  -0.094372               0.268081
# B_win_by_KO/TKO              -0.075351               0.247703
# B_win_by_Submission          -0.050420               0.122082
# B_win_by_TKO_Doctor_Stoppage -0.001469               0.072099
# B_wins                       -0.100831               0.312607
# B_Height_cms                  0.004384               0.046293
# B_Reach_cms                   0.002233               0.064147
# B_Weight_lbs                  0.004622               0.050444
# R_current_lose_streak         0.372184              -0.304523
# R_current_win_streak         -0.290888               0.347144
# R_draw                       NaN                    NaN
# R_avg_BODY_att               -0.053924               0.054601
# R_avg_BODY_landed            -0.062032               0.073579
# R_avg_CLINCH_att             -0.038217               0.058451
# R_avg_CLINCH_landed          -0.043268               0.067527
# R_avg_DISTANCE_att           -0.032102               0.046877
# R_avg_DISTANCE_landed        -0.058282               0.072989
# R_avg_GROUND_att             -0.094766               0.139427
# R_avg_GROUND_landed          -0.096740               0.145989
# R_avg_HEAD_att               -0.052190               0.081695
# R_avg_HEAD_landed            -0.100015               0.139399
# R_avg_KD                     -0.077674               0.106012
# R_avg_LEG_att                -0.040412               0.061307
# R_avg_LEG_landed             -0.042571               0.067858
# R_avg_PASS                   -0.081344               0.110700
# R_avg_REV                     0.029205              -0.058853
# R_avg_SIG_STR_att            -0.057264               0.084282
# R_avg_SIG_STR_landed         -0.096779               0.133510
# R_avg_SIG_STR_pct            -0.086668               0.126021
# R_avg_SUB_ATT                -0.012776              -0.002086
# R_avg_TD_att                 -0.013694               0.063040
# R_avg_TD_landed              -0.075555               0.118837
# R_avg_TD_pct                 -0.103166               0.112489
# R_avg_TOTAL_STR_att          -0.076812               0.100097
# R_avg_TOTAL_STR_landed       -0.106376               0.133257
# R_longest_win_streak         -0.156082               0.304127
# R_losses                      0.131803              -0.047696
# R_avg_opp_BODY_att            0.000685               0.009031
# R_avg_opp_BODY_landed         0.031270              -0.023058
# R_avg_opp_CLINCH_att          0.033802              -0.033606
# R_avg_opp_CLINCH_landed       0.044530              -0.045103
# R_avg_opp_DISTANCE_att       -0.002586               0.024974
# R_avg_opp_DISTANCE_landed     0.029128              -0.010268
# R_avg_opp_GROUND_att          0.133158              -0.138811
# R_avg_opp_GROUND_landed       0.143759              -0.147687
# R_avg_opp_HEAD_att            0.034639              -0.013386
# R_avg_opp_HEAD_landed         0.100999              -0.084583
# R_avg_opp_KD                  0.076189              -0.101126
# R_avg_opp_LEG_att            -0.011353               0.022622
# R_avg_opp_LEG_landed          0.002719               0.003827
# R_avg_opp_PASS                0.123703              -0.151468
# R_avg_opp_REV                 0.031878              -0.050620
# R_avg_opp_SIG_STR_att         0.027186              -0.006804
# R_avg_opp_SIG_STR_landed      0.079752              -0.064504
# R_avg_opp_SIG_STR_pct         0.122873              -0.143470
# R_avg_opp_SUB_ATT             0.065156              -0.074330
# R_avg_opp_TD_att              0.018552              -0.031564
# R_avg_opp_TD_landed           0.092966              -0.127571
# R_avg_opp_TD_pct              0.099654              -0.148374
# R_avg_opp_TOTAL_STR_att       0.051113              -0.031839
# R_avg_opp_TOTAL_STR_landed    0.097288              -0.085254
# R_total_rounds_fought        -0.031633               0.193530
# R_total_time_fought(seconds) -0.024916               0.071116
# R_total_title_bouts          -0.081221               0.244302
# R_win_by_Decision_Majority   -0.030045               0.095514
# R_win_by_Decision_Split      -0.000805               0.034011
# R_win_by_Decision_Unanimous  -0.100715               0.232750
# R_win_by_KO/TKO              -0.086167               0.227833
# R_win_by_Submission          -0.047248               0.105650
# R_win_by_TKO_Doctor_Stoppage -0.023706               0.029789
# R_wins                       -0.111216               0.276256
# R_Height_cms                  0.010508               0.021968
# R_Reach_cms                  -0.004002               0.053432
# R_Weight_lbs                  0.015504               0.046844
# B_age                         0.138502              -0.043014
# R_age                         0.031525               0.054018
#
#                               B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# Winner                       NaN     -0.115562       -0.101472
# title_bout                   NaN      0.020875        0.031579
# no_of_rounds                 NaN      0.039672        0.048708
# B_current_lose_streak        NaN     -0.029255       -0.050964
# B_current_win_streak         NaN      0.025614        0.034810
# B_draw                       NaN     NaN             NaN
# B_avg_BODY_att               NaN      1.000000        0.956557
# B_avg_BODY_landed            NaN      0.956557        1.000000
# B_avg_CLINCH_att             NaN      0.542261        0.596572
# B_avg_CLINCH_landed          NaN      0.541498        0.617678
# B_avg_DISTANCE_att           NaN      0.637469        0.547413
# B_avg_DISTANCE_landed        NaN      0.651353        0.593793
# B_avg_GROUND_att             NaN      0.016635        0.071471
# B_avg_GROUND_landed          NaN      0.035596        0.099931
# B_avg_HEAD_att               NaN      0.573491        0.511296
# B_avg_HEAD_landed            NaN      0.510097        0.495127
# B_avg_KD                     NaN      0.012957        0.013496
# B_avg_LEG_att                NaN      0.455676        0.410189
# B_avg_LEG_landed             NaN      0.456771        0.420973
# B_avg_PASS                   NaN     -0.065747       -0.024853
# B_avg_REV                    NaN     -0.036512       -0.039410
# B_avg_SIG_STR_att            NaN      0.700842        0.636071
# B_avg_SIG_STR_landed         NaN      0.736021        0.728444
# B_avg_SIG_STR_pct            NaN      0.048197        0.158118
# B_avg_SUB_ATT                NaN     -0.163767       -0.139154
# B_avg_TD_att                 NaN      0.020529        0.026956
# B_avg_TD_landed              NaN     -0.018305        0.014806
# B_avg_TD_pct                 NaN     -0.056203       -0.013478
# B_avg_TOTAL_STR_att          NaN      0.656935        0.625788
# B_avg_TOTAL_STR_landed       NaN      0.554511        0.593075
# B_longest_win_streak         NaN      0.016587        0.023676
# B_losses                     NaN     -0.026048       -0.036534
# B_avg_opp_BODY_att           NaN      0.519553        0.476950
# B_avg_opp_BODY_landed        NaN      0.454311        0.434381
# B_avg_opp_CLINCH_att         NaN      0.354626        0.378551
# B_avg_opp_CLINCH_landed      NaN      0.331837        0.360682
# B_avg_opp_DISTANCE_att       NaN      0.548043        0.470596
# B_avg_opp_DISTANCE_landed    NaN      0.513950        0.441470
# B_avg_opp_GROUND_att         NaN     -0.096842       -0.101445
# B_avg_opp_GROUND_landed      NaN     -0.081768       -0.088330
# B_avg_opp_HEAD_att           NaN      0.520000        0.449042
# B_avg_opp_HEAD_landed        NaN      0.420564        0.361215
# B_avg_opp_KD                 NaN     -0.094046       -0.096488
# B_avg_opp_LEG_att            NaN      0.368817        0.323163
# B_avg_opp_LEG_landed         NaN      0.359294        0.318669
# B_avg_opp_PASS               NaN     -0.020384       -0.020987
# B_avg_opp_REV                NaN     -0.082992       -0.080308
# B_avg_opp_SIG_STR_att        NaN      0.557401        0.486343
# B_avg_opp_SIG_STR_landed     NaN      0.505578        0.448469
# B_avg_opp_SIG_STR_pct        NaN     -0.083996       -0.055236
# B_avg_opp_SUB_ATT            NaN     -0.058488       -0.028128
# B_avg_opp_TD_att             NaN      0.350884        0.359174
# B_avg_opp_TD_landed          NaN      0.163555        0.169924
# B_avg_opp_TD_pct             NaN     -0.028402       -0.027494
# B_avg_opp_TOTAL_STR_att      NaN      0.506895        0.455639
# B_avg_opp_TOTAL_STR_landed   NaN      0.339019        0.323107
# B_total_rounds_fought        NaN      0.078334        0.074789
# B_total_time_fought(seconds) NaN      0.512898        0.489345
# B_total_title_bouts          NaN     -0.025824       -0.013802
# B_win_by_Decision_Majority   NaN     -0.037876       -0.030072
# B_win_by_Decision_Split      NaN      0.127578        0.122853
# B_win_by_Decision_Unanimous  NaN      0.179366        0.176368
# B_win_by_KO/TKO              NaN     -0.068972       -0.054265
# B_win_by_Submission          NaN     -0.158750       -0.155257
# B_win_by_TKO_Doctor_Stoppage NaN     -0.058618       -0.045524
# B_wins                       NaN     -0.003222        0.005069
# B_Height_cms                 NaN     -0.213939       -0.176852
# B_Reach_cms                  NaN     -0.203220       -0.168959
# B_Weight_lbs                 NaN     -0.231925       -0.178640
# R_current_lose_streak        NaN     -0.001016       -0.023357
# R_current_win_streak         NaN      0.016884        0.026309
# R_draw                       NaN     NaN             NaN
# R_avg_BODY_att               NaN      0.160580        0.129577
# R_avg_BODY_landed            NaN      0.129868        0.104915
# R_avg_CLINCH_att             NaN      0.059818        0.052002
# R_avg_CLINCH_landed          NaN      0.051035        0.046094
# R_avg_DISTANCE_att           NaN      0.202092        0.166269
# R_avg_DISTANCE_landed        NaN      0.194849        0.161036
# R_avg_GROUND_att             NaN     -0.070148       -0.062707
# R_avg_GROUND_landed          NaN     -0.053041       -0.048168
# R_avg_HEAD_att               NaN      0.179942        0.148067
# R_avg_HEAD_landed            NaN      0.150450        0.126602
# R_avg_KD                     NaN     -0.040740       -0.030997
# R_avg_LEG_att                NaN      0.115425        0.093759
# R_avg_LEG_landed             NaN      0.110763        0.087103
# R_avg_PASS                   NaN     -0.054341       -0.047257
# R_avg_REV                    NaN     -0.047107       -0.049990
# R_avg_SIG_STR_att            NaN      0.189690        0.155478
# R_avg_SIG_STR_landed         NaN      0.168422        0.138857
# R_avg_SIG_STR_pct            NaN     -0.094108       -0.075802
# R_avg_SUB_ATT                NaN     -0.054206       -0.051659
# R_avg_TD_att                 NaN      0.013506        0.008947
# R_avg_TD_landed              NaN     -0.017741       -0.016700
# R_avg_TD_pct                 NaN     -0.043116       -0.038303
# R_avg_TOTAL_STR_att          NaN      0.161479        0.134670
# R_avg_TOTAL_STR_landed       NaN      0.094122        0.080912
# R_longest_win_streak         NaN      0.013406        0.013954
# R_losses                     NaN      0.046928        0.027775
# R_avg_opp_BODY_att           NaN      0.191630        0.150796
# R_avg_opp_BODY_landed        NaN      0.165950        0.131850
# R_avg_opp_CLINCH_att         NaN      0.066966        0.046601
# R_avg_opp_CLINCH_landed      NaN      0.064058        0.044409
# R_avg_opp_DISTANCE_att       NaN      0.196253        0.152156
# R_avg_opp_DISTANCE_landed    NaN      0.193648        0.151945
# R_avg_opp_GROUND_att         NaN     -0.040422       -0.047167
# R_avg_opp_GROUND_landed      NaN     -0.024286       -0.033745
# R_avg_opp_HEAD_att           NaN      0.171829        0.126991
# R_avg_opp_HEAD_landed        NaN      0.139173        0.097236
# R_avg_opp_KD                 NaN     -0.029309       -0.024222
# R_avg_opp_LEG_att            NaN      0.158183        0.131116
# R_avg_opp_LEG_landed         NaN      0.162555        0.136266
# R_avg_opp_PASS               NaN     -0.006444       -0.021713
# R_avg_opp_REV                NaN     -0.039127       -0.039408
# R_avg_opp_SIG_STR_att        NaN      0.190223        0.143759
# R_avg_opp_SIG_STR_landed     NaN      0.179930        0.135298
# R_avg_opp_SIG_STR_pct        NaN     -0.010592       -0.005584
# R_avg_opp_SUB_ATT            NaN     -0.068152       -0.069321
# R_avg_opp_TD_att             NaN      0.045073        0.027071
# R_avg_opp_TD_landed          NaN     -0.004521       -0.018896
# R_avg_opp_TD_pct             NaN     -0.014250       -0.020503
# R_avg_opp_TOTAL_STR_att      NaN      0.172324        0.127651
# R_avg_opp_TOTAL_STR_landed   NaN      0.115600        0.081866
# R_total_rounds_fought        NaN      0.077102        0.061619
# R_total_time_fought(seconds) NaN      0.109722        0.081815
# R_total_title_bouts          NaN     -0.006708        0.004926
# R_win_by_Decision_Majority   NaN     -0.052464       -0.042462
# R_win_by_Decision_Split      NaN      0.082209        0.072328
# R_win_by_Decision_Unanimous  NaN      0.078732        0.065611
# R_win_by_KO/TKO              NaN     -0.033110       -0.023392
# R_win_by_Submission          NaN      0.035703        0.033220
# R_win_by_TKO_Doctor_Stoppage NaN     -0.055391       -0.047699
# R_wins                       NaN      0.039266        0.037079
# R_Height_cms                 NaN     -0.232117       -0.188701
# R_Reach_cms                  NaN     -0.230957       -0.185562
# R_Weight_lbs                 NaN     -0.238797       -0.184975
# B_age                        NaN     -0.031966       -0.018205
# R_age                        NaN      0.033962        0.037520
#
#                               B_avg_CLINCH_att  B_avg_CLINCH_landed  \
# Winner                       -0.035410         -0.034547
# title_bout                    0.018988          0.021995
# no_of_rounds                  0.011374          0.015205
# B_current_lose_streak        -0.046607         -0.054079
# B_current_win_streak          0.012627          0.016582
# B_draw                       NaN               NaN
# B_avg_BODY_att                0.542261          0.541498
# B_avg_BODY_landed             0.596572          0.617678
# B_avg_CLINCH_att              1.000000          0.969522
# B_avg_CLINCH_landed           0.969522          1.000000
# B_avg_DISTANCE_att            0.267361          0.221299
# B_avg_DISTANCE_landed         0.284242          0.255172
# B_avg_GROUND_att              0.079213          0.074150
# B_avg_GROUND_landed           0.084986          0.087239
# B_avg_HEAD_att                0.375101          0.315923
# B_avg_HEAD_landed             0.438753          0.407437
# B_avg_KD                      0.001473         -0.004211
# B_avg_LEG_att                 0.324534          0.318429
# B_avg_LEG_landed              0.348676          0.351782
# B_avg_PASS                   -0.049981         -0.041296
# B_avg_REV                    -0.027530         -0.035059
# B_avg_SIG_STR_att             0.443613          0.393735
# B_avg_SIG_STR_landed          0.559905          0.544439
# B_avg_SIG_STR_pct             0.193941          0.262564
# B_avg_SUB_ATT                -0.087983         -0.084545
# B_avg_TD_att                  0.089064          0.074809
# B_avg_TD_landed               0.067099          0.060157
# B_avg_TD_pct                 -0.000351          0.000616
# B_avg_TOTAL_STR_att           0.494431          0.453992
# B_avg_TOTAL_STR_landed        0.539667          0.536136
# B_longest_win_streak         -0.002331         -0.000628
# B_losses                     -0.034529         -0.041069
# B_avg_opp_BODY_att            0.338079          0.318084
# B_avg_opp_BODY_landed         0.349231          0.336643
# B_avg_opp_CLINCH_att          0.579921          0.548585
# B_avg_opp_CLINCH_landed       0.525648          0.517917
# B_avg_opp_DISTANCE_att        0.223374          0.182439
# B_avg_opp_DISTANCE_landed     0.221052          0.182357
# B_avg_opp_GROUND_att         -0.057011         -0.055877
# B_avg_opp_GROUND_landed      -0.057977         -0.053557
# B_avg_opp_HEAD_att            0.259116          0.211516
# B_avg_opp_HEAD_landed         0.242991          0.200708
# B_avg_opp_KD                 -0.085777         -0.103917
# B_avg_opp_LEG_att             0.182309          0.173478
# B_avg_opp_LEG_landed          0.193328          0.189337
# B_avg_opp_PASS               -0.000620         -0.002760
# B_avg_opp_REV                -0.056195         -0.069670
# B_avg_opp_SIG_STR_att         0.289894          0.246348
# B_avg_opp_SIG_STR_landed      0.311591          0.277538
# B_avg_opp_SIG_STR_pct         0.051171          0.067634
# B_avg_opp_SUB_ATT            -0.013175         -0.021867
# B_avg_opp_TD_att              0.308597          0.310070
# B_avg_opp_TD_landed           0.178291          0.164575
# B_avg_opp_TD_pct              0.024177          0.015978
# B_avg_opp_TOTAL_STR_att       0.309901          0.273585
# B_avg_opp_TOTAL_STR_landed    0.288841          0.270838
# B_total_rounds_fought         0.035903          0.030010
# B_total_time_fought(seconds)  0.358121          0.334456
# B_total_title_bouts           0.009088          0.016149
# B_win_by_Decision_Majority    0.003778          0.021033
# B_win_by_Decision_Split       0.070274          0.057942
# B_win_by_Decision_Unanimous   0.107666          0.100942
# B_win_by_KO/TKO              -0.034019         -0.028409
# B_win_by_Submission          -0.137711         -0.132950
# B_win_by_TKO_Doctor_Stoppage -0.007981         -0.004303
# B_wins                       -0.011663         -0.010844
# B_Height_cms                 -0.078909         -0.061611
# B_Reach_cms                  -0.106750         -0.083385
# B_Weight_lbs                 -0.056401         -0.039487
# R_current_lose_streak        -0.019557         -0.025060
# R_current_win_streak          0.010199          0.009640
# R_draw                       NaN               NaN
# R_avg_BODY_att                0.052633          0.056641
# R_avg_BODY_landed             0.036767          0.039162
# R_avg_CLINCH_att              0.023133          0.020860
# R_avg_CLINCH_landed           0.014306          0.012760
# R_avg_DISTANCE_att            0.050881          0.054601
# R_avg_DISTANCE_landed         0.054087          0.058303
# R_avg_GROUND_att             -0.062450         -0.056640
# R_avg_GROUND_landed          -0.054910         -0.048347
# R_avg_HEAD_att                0.034362          0.038268
# R_avg_HEAD_landed             0.028965          0.035146
# R_avg_KD                     -0.005177         -0.006645
# R_avg_LEG_att                 0.019934          0.023965
# R_avg_LEG_landed              0.011457          0.013804
# R_avg_PASS                   -0.014480         -0.020224
# R_avg_REV                    -0.003121         -0.009515
# R_avg_SIG_STR_att             0.039662          0.044087
# R_avg_SIG_STR_landed          0.033128          0.038626
# R_avg_SIG_STR_pct            -0.006998         -0.004912
# R_avg_SUB_ATT                -0.007139         -0.012623
# R_avg_TD_att                 -0.020636         -0.022497
# R_avg_TD_landed              -0.030259         -0.034114
# R_avg_TD_pct                 -0.019316         -0.018862
# R_avg_TOTAL_STR_att           0.037642          0.041204
# R_avg_TOTAL_STR_landed        0.021155          0.023679
# R_longest_win_streak         -0.007706         -0.006777
# R_losses                     -0.014036         -0.015928
# R_avg_opp_BODY_att            0.029996          0.025071
# R_avg_opp_BODY_landed         0.026090          0.019565
# R_avg_opp_CLINCH_att          0.015311          0.003027
# R_avg_opp_CLINCH_landed       0.012371          0.000630
# R_avg_opp_DISTANCE_att        0.033527          0.033315
# R_avg_opp_DISTANCE_landed     0.035232          0.036286
# R_avg_opp_GROUND_att         -0.004768         -0.011832
# R_avg_opp_GROUND_landed       0.003960          0.000850
# R_avg_opp_HEAD_att            0.027584          0.023786
# R_avg_opp_HEAD_landed         0.019361          0.016260
# R_avg_opp_KD                 -0.020037         -0.015136
# R_avg_opp_LEG_att             0.049508          0.053471
# R_avg_opp_LEG_landed          0.062054          0.065046
# R_avg_opp_PASS               -0.007584         -0.011295
# R_avg_opp_REV                -0.019522         -0.027872
# R_avg_opp_SIG_STR_att         0.033477          0.030114
# R_avg_opp_SIG_STR_landed      0.035393          0.032271
# R_avg_opp_SIG_STR_pct         0.031860          0.033170
# R_avg_opp_SUB_ATT            -0.039705         -0.044885
# R_avg_opp_TD_att             -0.020647         -0.026212
# R_avg_opp_TD_landed          -0.001548         -0.009571
# R_avg_opp_TD_pct              0.024636          0.015027
# R_avg_opp_TOTAL_STR_att       0.032934          0.025219
# R_avg_opp_TOTAL_STR_landed    0.024758          0.014800
# R_total_rounds_fought        -0.009142         -0.009063
# R_total_time_fought(seconds)  0.008557          0.007410
# R_total_title_bouts           0.010292          0.012370
# R_win_by_Decision_Majority   -0.002288          0.004331
# R_win_by_Decision_Split       0.028979          0.025297
# R_win_by_Decision_Unanimous  -0.004021         -0.003854
# R_win_by_KO/TKO              -0.020020         -0.014142
# R_win_by_Submission           0.000331          0.001719
# R_win_by_TKO_Doctor_Stoppage -0.038458         -0.037998
# R_wins                       -0.010451         -0.006978
# R_Height_cms                 -0.078606         -0.065979
# R_Reach_cms                  -0.082674         -0.068737
# R_Weight_lbs                 -0.067416         -0.048922
# B_age                         0.008726          0.030429
# R_age                         0.021192          0.026945
#
#                               B_avg_DISTANCE_att  B_avg_DISTANCE_landed  \
# Winner                       -0.120555           -0.116754
# title_bout                    0.013246            0.026187
# no_of_rounds                  0.041598            0.067010
# B_current_lose_streak         0.004314           -0.031311
# B_current_win_streak          0.014331            0.041153
# B_draw                       NaN                 NaN
# B_avg_BODY_att                0.637469            0.651353
# B_avg_BODY_landed             0.547413            0.593793
# B_avg_CLINCH_att              0.267361            0.284242
# B_avg_CLINCH_landed           0.221299            0.255172
# B_avg_DISTANCE_att            1.000000            0.939332
# B_avg_DISTANCE_landed         0.939332            1.000000
# B_avg_GROUND_att             -0.153016           -0.161007
# B_avg_GROUND_landed          -0.154521           -0.150768
# B_avg_HEAD_att                0.946078            0.869271
# B_avg_HEAD_landed             0.777227            0.828540
# B_avg_KD                      0.018090            0.068131
# B_avg_LEG_att                 0.548244            0.586679
# B_avg_LEG_landed              0.539382            0.598982
# B_avg_PASS                   -0.169948           -0.174606
# B_avg_REV                    -0.071480           -0.068372
# B_avg_SIG_STR_att             0.961814            0.905853
# B_avg_SIG_STR_landed          0.832389            0.896166
# B_avg_SIG_STR_pct            -0.269096           -0.077956
# B_avg_SUB_ATT                -0.215603           -0.212821
# B_avg_TD_att                 -0.031167           -0.076393
# B_avg_TD_landed              -0.112308           -0.135298
# B_avg_TD_pct                 -0.138897           -0.132818
# B_avg_TOTAL_STR_att           0.819204            0.764370
# B_avg_TOTAL_STR_landed        0.506882            0.541646
# B_longest_win_streak          0.015911            0.038643
# B_losses                      0.002929           -0.026269
# B_avg_opp_BODY_att            0.625955            0.624220
# B_avg_opp_BODY_landed         0.526670            0.531551
# B_avg_opp_CLINCH_att          0.199184            0.197105
# B_avg_opp_CLINCH_landed       0.163797            0.166002
# B_avg_opp_DISTANCE_att        0.878679            0.848256
# B_avg_opp_DISTANCE_landed     0.831142            0.806841
# B_avg_opp_GROUND_att         -0.118739           -0.128336
# B_avg_opp_GROUND_landed      -0.112334           -0.118754
# B_avg_opp_HEAD_att            0.824616            0.790284
# B_avg_opp_HEAD_landed         0.653462            0.625440
# B_avg_opp_KD                 -0.004931           -0.011454
# B_avg_opp_LEG_att             0.518758            0.498893
# B_avg_opp_LEG_landed          0.506894            0.490426
# B_avg_opp_PASS               -0.066905           -0.077210
# B_avg_opp_REV                -0.096858           -0.117396
# B_avg_opp_SIG_STR_att         0.844656            0.813498
# B_avg_opp_SIG_STR_landed      0.725195            0.702699
# B_avg_opp_SIG_STR_pct        -0.187651           -0.172312
# B_avg_opp_SUB_ATT            -0.151373           -0.177922
# B_avg_opp_TD_att              0.279056            0.270597
# B_avg_opp_TD_landed           0.084776            0.063085
# B_avg_opp_TD_pct             -0.087005           -0.092425
# B_avg_opp_TOTAL_STR_att       0.724283            0.696719
# B_avg_opp_TOTAL_STR_landed    0.418428            0.403441
# B_total_rounds_fought         0.111245            0.095411
# B_total_time_fought(seconds)  0.564203            0.517664
# B_total_title_bouts          -0.026095           -0.013844
# B_win_by_Decision_Majority   -0.043875           -0.032055
# B_win_by_Decision_Split       0.204348            0.166231
# B_win_by_Decision_Unanimous   0.173374            0.161305
# B_win_by_KO/TKO              -0.064785           -0.030214
# B_win_by_Submission          -0.168395           -0.166577
# B_win_by_TKO_Doctor_Stoppage -0.039087           -0.038074
# B_wins                        0.007747            0.014985
# B_Height_cms                 -0.230493           -0.192181
# B_Reach_cms                  -0.227526           -0.199504
# B_Weight_lbs                 -0.260864           -0.217346
# R_current_lose_streak         0.009910           -0.014092
# R_current_win_streak          0.010921            0.023296
# R_draw                       NaN                 NaN
# R_avg_BODY_att                0.168080            0.168832
# R_avg_BODY_landed             0.142824            0.148286
# R_avg_CLINCH_att              0.064525            0.071567
# R_avg_CLINCH_landed           0.065361            0.074366
# R_avg_DISTANCE_att            0.216748            0.223482
# R_avg_DISTANCE_landed         0.218801            0.234572
# R_avg_GROUND_att             -0.078751           -0.076740
# R_avg_GROUND_landed          -0.059450           -0.053331
# R_avg_HEAD_att                0.194004            0.203620
# R_avg_HEAD_landed             0.176781            0.200823
# R_avg_KD                     -0.037500           -0.026010
# R_avg_LEG_att                 0.118256            0.119384
# R_avg_LEG_landed              0.116551            0.119293
# R_avg_PASS                   -0.067941           -0.069738
# R_avg_REV                    -0.014045           -0.027185
# R_avg_SIG_STR_att             0.202767            0.210848
# R_avg_SIG_STR_landed          0.191497            0.210081
# R_avg_SIG_STR_pct            -0.073285           -0.056716
# R_avg_SUB_ATT                -0.068901           -0.077609
# R_avg_TD_att                 -0.001711           -0.014006
# R_avg_TD_landed              -0.021359           -0.034004
# R_avg_TD_pct                 -0.055226           -0.055691
# R_avg_TOTAL_STR_att           0.170214            0.174106
# R_avg_TOTAL_STR_landed        0.104499            0.111296
# R_longest_win_streak          0.011601            0.037633
# R_losses                      0.063749            0.075117
# R_avg_opp_BODY_att            0.211063            0.217064
# R_avg_opp_BODY_landed         0.175796            0.179847
# R_avg_opp_CLINCH_att          0.059311            0.056314
# R_avg_opp_CLINCH_landed       0.057365            0.056102
# R_avg_opp_DISTANCE_att        0.222932            0.228922
# ...
# B_avg_HEAD_landed            -0.160562     -0.157896    -0.148387
# B_avg_KD                      0.099125      0.104503     0.112509
# B_avg_LEG_att                -0.136383     -0.131396    -0.162269
# B_avg_LEG_landed             -0.123238     -0.119353    -0.145842
# B_avg_PASS                   -0.047445     -0.039268    -0.060969
# B_avg_REV                    -0.110012     -0.115584    -0.130567
# B_avg_SIG_STR_att            -0.239409     -0.238658    -0.254856
# B_avg_SIG_STR_landed         -0.195675     -0.191964    -0.191747
# B_avg_SIG_STR_pct             0.115080      0.127480     0.159516
# B_avg_SUB_ATT                -0.085522     -0.083201    -0.120107
# B_avg_TD_att                 -0.107253     -0.087343    -0.121265
# B_avg_TD_landed              -0.094321     -0.067030    -0.090685
# B_avg_TD_pct                 -0.075069     -0.056789    -0.061486
# B_avg_TOTAL_STR_att          -0.234766     -0.231838    -0.251454
# B_avg_TOTAL_STR_landed       -0.164970     -0.158795    -0.166821
# B_longest_win_streak          0.121654      0.150317     0.149266
# B_losses                      0.057337      0.055835     0.066524
# B_avg_opp_BODY_att           -0.234801     -0.229353    -0.248901
# B_avg_opp_BODY_landed        -0.193939     -0.192190    -0.193302
# B_avg_opp_CLINCH_att         -0.084946     -0.086751    -0.072544
# B_avg_opp_CLINCH_landed      -0.075442     -0.074501    -0.055167
# B_avg_opp_DISTANCE_att       -0.247335     -0.250269    -0.271784
# B_avg_opp_DISTANCE_landed    -0.204834     -0.211574    -0.225940
# B_avg_opp_GROUND_att         -0.035408     -0.042920    -0.032242
# B_avg_opp_GROUND_landed      -0.035994     -0.042810    -0.026490
# B_avg_opp_HEAD_att           -0.243425     -0.250543    -0.259051
# B_avg_opp_HEAD_landed        -0.181064     -0.193946    -0.179488
# B_avg_opp_KD                  0.078638      0.064782     0.079739
# B_avg_opp_LEG_att            -0.139763     -0.135769    -0.184407
# B_avg_opp_LEG_landed         -0.120325     -0.117092    -0.164771
# B_avg_opp_PASS               -0.092891     -0.092996    -0.103881
# B_avg_opp_REV                -0.098077     -0.089753    -0.112496
# B_avg_opp_SIG_STR_att        -0.255419     -0.259937    -0.276223
# B_avg_opp_SIG_STR_landed     -0.208679     -0.216464    -0.218458
# B_avg_opp_SIG_STR_pct         0.078001      0.065876     0.104204
# B_avg_opp_SUB_ATT            -0.098390     -0.083454    -0.125555
# B_avg_opp_TD_att             -0.120881     -0.111375    -0.170859
# B_avg_opp_TD_landed          -0.097478     -0.094174    -0.144429
# B_avg_opp_TD_pct             -0.071758     -0.070448    -0.091304
# B_avg_opp_TOTAL_STR_att      -0.270328     -0.276263    -0.288009
# B_avg_opp_TOTAL_STR_landed   -0.203796     -0.210384    -0.207577
# B_total_rounds_fought         0.045106      0.063049     0.055068
# B_total_time_fought(seconds) -0.224672     -0.209225    -0.251311
# B_total_title_bouts           0.096377      0.110972     0.138554
# B_win_by_Decision_Majority    0.080053      0.070416     0.114625
# B_win_by_Decision_Split      -0.033327     -0.028763    -0.079987
# B_win_by_Decision_Unanimous  -0.025721      0.002426    -0.032389
# B_win_by_KO/TKO               0.242677      0.246169     0.311685
# B_win_by_Submission           0.014984      0.031072     0.005093
# B_win_by_TKO_Doctor_Stoppage  0.054430      0.065398     0.060553
# B_wins                        0.122872      0.143732     0.145892
# B_Height_cms                  0.719610      0.687502     0.766257
# B_Reach_cms                   0.686445      0.662708     0.732723
# B_Weight_lbs                  0.768939      0.736753     0.949410
# R_current_lose_streak        -0.015038     -0.037515     0.000115
# R_current_win_streak          0.018164      0.054754     0.004470
# R_draw                       NaN           NaN          NaN
# R_avg_BODY_att               -0.237032     -0.220196    -0.264838
# R_avg_BODY_landed            -0.183813     -0.168672    -0.197266
# R_avg_CLINCH_att             -0.059879     -0.072608    -0.034888
# R_avg_CLINCH_landed          -0.037724     -0.044928    -0.014634
# R_avg_DISTANCE_att           -0.283462     -0.285700    -0.312109
# R_avg_DISTANCE_landed        -0.230677     -0.240339    -0.263208
# R_avg_GROUND_att              0.021325      0.042733     0.031288
# R_avg_GROUND_landed           0.031953      0.050672     0.042400
# R_avg_HEAD_att               -0.264370     -0.269212    -0.280562
# R_avg_HEAD_landed            -0.165661     -0.179083    -0.178767
# R_avg_KD                      0.127148      0.126783     0.171541
# R_avg_LEG_att                -0.165586     -0.156582    -0.189566
# R_avg_LEG_landed             -0.145467     -0.143327    -0.166878
# R_avg_PASS                   -0.039981     -0.021653    -0.063984
# R_avg_REV                    -0.064601     -0.061710    -0.141264
# R_avg_SIG_STR_att            -0.278308     -0.278072    -0.299602
# R_avg_SIG_STR_landed         -0.203301     -0.207536    -0.221718
# R_avg_SIG_STR_pct             0.211899      0.215211     0.222344
# R_avg_SUB_ATT                -0.022320      0.001642    -0.099345
# R_avg_TD_att                 -0.202109     -0.161744    -0.156238
# R_avg_TD_landed              -0.163363     -0.103860    -0.114153
# R_avg_TD_pct                 -0.086594     -0.040675    -0.065144
# R_avg_TOTAL_STR_att          -0.277279     -0.269742    -0.291191
# R_avg_TOTAL_STR_landed       -0.180276     -0.169832    -0.184115
# R_longest_win_streak          0.093610      0.132845     0.095005
# R_losses                      0.025451      0.020355     0.066818
# R_avg_opp_BODY_att           -0.312416     -0.323113    -0.278210
# R_avg_opp_BODY_landed        -0.286554     -0.300947    -0.231835
# R_avg_opp_CLINCH_att         -0.113863     -0.129020    -0.064100
# R_avg_opp_CLINCH_landed      -0.122156     -0.139703    -0.063607
# R_avg_opp_DISTANCE_att       -0.322130     -0.346226    -0.316196
# R_avg_opp_DISTANCE_landed    -0.254225     -0.289155    -0.268423
# R_avg_opp_GROUND_att         -0.012502     -0.006935    -0.040153
# R_avg_opp_GROUND_landed      -0.016490     -0.012484    -0.035201
# R_avg_opp_HEAD_att           -0.318366     -0.345363    -0.305059
# R_avg_opp_HEAD_landed        -0.218845     -0.261039    -0.221743
# R_avg_opp_KD                  0.099083      0.060743     0.097357
# R_avg_opp_LEG_att            -0.145479     -0.149125    -0.208456
# R_avg_opp_LEG_landed         -0.136925     -0.140145    -0.195694
# R_avg_opp_PASS               -0.114451     -0.109212    -0.125457
# R_avg_opp_REV                -0.084992     -0.069487    -0.107946
# R_avg_opp_SIG_STR_att        -0.327364     -0.351657    -0.319262
# R_avg_opp_SIG_STR_landed     -0.260603     -0.294767    -0.262956
# R_avg_opp_SIG_STR_pct         0.127854      0.111492     0.121225
# R_avg_opp_SUB_ATT            -0.075998     -0.061934    -0.086213
# R_avg_opp_TD_att             -0.157750     -0.154614    -0.212132
# R_avg_opp_TD_landed          -0.133926     -0.140058    -0.178995
# R_avg_opp_TD_pct             -0.087809     -0.099007    -0.145504
# R_avg_opp_TOTAL_STR_att      -0.354384     -0.380938    -0.343689
# R_avg_opp_TOTAL_STR_landed   -0.270874     -0.302465    -0.265545
# R_total_rounds_fought        -0.015510      0.013717     0.014193
# R_total_time_fought(seconds) -0.313810     -0.289994    -0.301982
# R_total_title_bouts           0.021951      0.057718     0.086224
# R_win_by_Decision_Majority    0.125325      0.136851     0.151216
# R_win_by_Decision_Split      -0.125772     -0.130493    -0.105916
# R_win_by_Decision_Unanimous  -0.104478     -0.074303    -0.102459
# R_win_by_KO/TKO               0.251735      0.257322     0.315544
# R_win_by_Submission           0.080335      0.114567     0.000435
# R_win_by_TKO_Doctor_Stoppage  0.022204      0.057493     0.051233
# R_wins                        0.100179      0.132300     0.111773
# R_Height_cms                  1.000000      0.895216     0.790584
# R_Reach_cms                   0.895216      1.000000     0.756817
# R_Weight_lbs                  0.790584      0.756817     1.000000
# B_age                         0.204810      0.193517     0.258839
# R_age                         0.106622      0.089485     0.234385
#
#                                  B_age     R_age
# Winner                        0.082052 -0.151100
# title_bout                    0.063266  0.014772
# no_of_rounds                  0.139494  0.097148
# B_current_lose_streak         0.138502  0.031525
# B_current_win_streak         -0.043014  0.054018
# B_draw                       NaN       NaN
# B_avg_BODY_att               -0.031966  0.033962
# B_avg_BODY_landed            -0.018205  0.037520
# B_avg_CLINCH_att              0.008726  0.021192
# B_avg_CLINCH_landed           0.030429  0.026945
# B_avg_DISTANCE_att           -0.069093  0.036726
# B_avg_DISTANCE_landed        -0.051247  0.057438
# B_avg_GROUND_att             -0.058793  0.002074
# B_avg_GROUND_landed          -0.037742  0.019913
# B_avg_HEAD_att               -0.087344  0.037863
# B_avg_HEAD_landed            -0.068394  0.067678
# B_avg_KD                      0.023494  0.042229
# B_avg_LEG_att                 0.015238  0.014270
# B_avg_LEG_landed              0.024620  0.023739
# B_avg_PASS                   -0.085744 -0.053935
# B_avg_REV                    -0.126712 -0.092593
# B_avg_SIG_STR_att            -0.075384  0.038836
# B_avg_SIG_STR_landed         -0.046963  0.063876
# B_avg_SIG_STR_pct             0.078780  0.062209
# B_avg_SUB_ATT                -0.129968 -0.117918
# B_avg_TD_att                 -0.012155 -0.025946
# B_avg_TD_landed              -0.063808 -0.027066
# B_avg_TD_pct                 -0.067898 -0.040698
# B_avg_TOTAL_STR_att          -0.081381  0.012503
# B_avg_TOTAL_STR_landed       -0.049868  0.006686
# B_longest_win_streak          0.242814  0.161866
# B_losses                      0.401384  0.175727
# B_avg_opp_BODY_att           -0.029152  0.028895
# B_avg_opp_BODY_landed        -0.010209  0.026374
# B_avg_opp_CLINCH_att          0.058777  0.005270
# B_avg_opp_CLINCH_landed       0.064273  0.016160
# B_avg_opp_DISTANCE_att       -0.025529  0.037815
# B_avg_opp_DISTANCE_landed    -0.014997  0.049765
# B_avg_opp_GROUND_att          0.010542 -0.047929
# B_avg_opp_GROUND_landed       0.017317 -0.030109
# B_avg_opp_HEAD_att           -0.011432  0.024406
# B_avg_opp_HEAD_landed         0.013227  0.035406
# B_avg_opp_KD                  0.123839  0.010884
# B_avg_opp_LEG_att             0.004748  0.022995
# B_avg_opp_LEG_landed          0.012519  0.022652
# B_avg_opp_PASS               -0.058238 -0.053369
# B_avg_opp_REV                -0.081674 -0.090512
# B_avg_opp_SIG_STR_att        -0.013372  0.027590
# B_avg_opp_SIG_STR_landed      0.009700  0.037522
# B_avg_opp_SIG_STR_pct         0.054987  0.036995
# B_avg_opp_SUB_ATT            -0.087413 -0.079286
# B_avg_opp_TD_att             -0.061640 -0.018095
# B_avg_opp_TD_landed          -0.065211 -0.048722
# B_avg_opp_TD_pct             -0.065116 -0.073158
# B_avg_opp_TOTAL_STR_att      -0.023089  0.005400
# B_avg_opp_TOTAL_STR_landed   -0.007082 -0.007690
# B_total_rounds_fought         0.384898  0.191595
# B_total_time_fought(seconds) -0.002081  0.004629
# B_total_title_bouts           0.287137  0.073095
# B_win_by_Decision_Majority    0.081661  0.028127
# B_win_by_Decision_Split       0.143882  0.066207
# B_win_by_Decision_Unanimous   0.230193  0.122306
# B_win_by_KO/TKO               0.322767  0.211479
# B_win_by_Submission           0.113090  0.033654
# B_win_by_TKO_Doctor_Stoppage  0.082593  0.028020
# B_wins                        0.344790  0.189922
# B_Height_cms                  0.113067  0.201459
# B_Reach_cms                   0.095728  0.200864
# B_Weight_lbs                  0.244984  0.259637
# R_current_lose_streak         0.056627  0.194228
# R_current_win_streak          0.018797 -0.067703
# R_draw                       NaN       NaN
# R_avg_BODY_att               -0.021761 -0.020590
# R_avg_BODY_landed            -0.004200 -0.005703
# R_avg_CLINCH_att              0.025084 -0.001980
# R_avg_CLINCH_landed           0.030835  0.019448
# R_avg_DISTANCE_att           -0.017018 -0.013271
# R_avg_DISTANCE_landed        -0.007166 -0.009068
# R_avg_GROUND_att              0.030152 -0.075495
# R_avg_GROUND_landed           0.037036 -0.051320
# R_avg_HEAD_att                0.000319 -0.035290
# R_avg_HEAD_landed             0.029129 -0.036689
# R_avg_KD                      0.071814  0.037317
# R_avg_LEG_att                -0.016605  0.021416
# R_avg_LEG_landed             -0.012540  0.025081
# R_avg_PASS                   -0.015727 -0.067347
# R_avg_REV                    -0.076993 -0.086995
# R_avg_SIG_STR_att            -0.005829 -0.029024
# R_avg_SIG_STR_landed          0.015215 -0.019803
# R_avg_SIG_STR_pct             0.058662  0.050475
# R_avg_SUB_ATT                -0.090322 -0.173917
# R_avg_TD_att                 -0.030499 -0.026265
# R_avg_TD_landed              -0.023926 -0.104725
# R_avg_TD_pct                 -0.035271 -0.116116
# R_avg_TOTAL_STR_att          -0.020380 -0.033957
# R_avg_TOTAL_STR_landed       -0.015325 -0.022653
# R_longest_win_streak          0.159486  0.261330
# R_losses                      0.131736  0.450567
# R_avg_opp_BODY_att           -0.016310 -0.000096
# R_avg_opp_BODY_landed        -0.013095  0.010815
# R_avg_opp_CLINCH_att         -0.023432  0.021046
# R_avg_opp_CLINCH_landed      -0.017052  0.037997
# R_avg_opp_DISTANCE_att       -0.015783  0.044280
# R_avg_opp_DISTANCE_landed    -0.006332  0.056331
# R_avg_opp_GROUND_att         -0.025280 -0.023644
# R_avg_opp_GROUND_landed      -0.009659 -0.012801
# R_avg_opp_HEAD_att           -0.025026  0.046830
# R_avg_opp_HEAD_landed        -0.013076  0.066537
# R_avg_opp_KD                  0.031170  0.130944
# R_avg_opp_LEG_att            -0.001879  0.020486
# R_avg_opp_LEG_landed         -0.001633  0.025544
# R_avg_opp_PASS               -0.078126 -0.060610
# R_avg_opp_REV                -0.067497 -0.135069
# R_avg_opp_SIG_STR_att        -0.023287  0.041141
# R_avg_opp_SIG_STR_landed     -0.012949  0.055817
# R_avg_opp_SIG_STR_pct         0.016770  0.021671
# R_avg_opp_SUB_ATT            -0.081529 -0.090249
# R_avg_opp_TD_att             -0.082625 -0.071848
# R_avg_opp_TD_landed          -0.087358 -0.059624
# R_avg_opp_TD_pct             -0.082151 -0.050515
# R_avg_opp_TOTAL_STR_att      -0.048459  0.008813
# R_avg_opp_TOTAL_STR_landed   -0.053419 -0.009047
# R_total_rounds_fought         0.162653  0.432317
# R_total_time_fought(seconds) -0.024536  0.024572
# R_total_title_bouts           0.135362  0.233220
# R_win_by_Decision_Majority    0.059486  0.086689
# R_win_by_Decision_Split       0.046301  0.160571
# R_win_by_Decision_Unanimous   0.095398  0.252787
# R_win_by_KO/TKO               0.232960  0.366099
# R_win_by_Submission           0.040892  0.127605
# R_win_by_TKO_Doctor_Stoppage  0.048452  0.119296
# R_wins                        0.194363  0.394892
# R_Height_cms                  0.204810  0.106622
# R_Reach_cms                   0.193517  0.089485
# R_Weight_lbs                  0.258839  0.234385
# B_age                         1.000000  0.184525
# R_age                         0.184525  1.000000

# %%
del df['R_fighter']
del df['B_fighter']
del df['Referee']
del df['date']
del df['location']
del df['title_bout']
del df['no_of_rounds']
del df['R_draw']
del df['B_draw']
del df['R_wins']
del df['B_wins']
del df['R_losses']
del df['B_losses']
del df['B_current_lose_streak']
del df['R_current_lose_streak']
del df['B_longest_win_streak']
del df['R_longest_win_streak']
del df['B_age']
del df['R_age']
del df['B_total_title_bouts']
del df['R_total_title_bouts']
del df['B_avg_SIG_STR_pct']
del df['R_avg_SIG_STR_pct']
del df['B_avg_opp_SIG_STR_pct']
del df['R_avg_opp_SIG_STR_pct']
del df['B_avg_SUB_ATT']
del df['R_avg_SUB_ATT']
del df['B_avg_opp_SUB_ATT']
del df['R_avg_opp_SUB_ATT']
del df['B_avg_KD']
del df['R_avg_KD']
del df['B_avg_PASS']
del df['R_avg_PASS']
del df['B_avg_REV']
del df['R_avg_REV']
del df['B_avg_opp_KD']
del df['R_avg_opp_KD']
del df['B_avg_opp_PASS']
del df['R_avg_opp_PASS']
del df['B_avg_opp_REV']
del df['R_avg_opp_REV']
del df['B_current_win_streak']
del df['R_current_win_streak']
del df['B_avg_BODY_att']
del df['R_avg_BODY_att']
del df['B_avg_CLINCH_att']
del df['R_avg_CLINCH_att']
del df['B_avg_DISTANCE_att']
del df['R_avg_DISTANCE_att']
del df['B_avg_GROUND_att']
del df['R_avg_GROUND_att']
del df['B_avg_HEAD_att']
del df['R_avg_HEAD_att']
del df['B_avg_LEG_att']
del df['R_avg_LEG_att']
del df['B_avg_SIG_STR_att']
del df['R_avg_SIG_STR_att']
del df['B_avg_TD_att']
del df['R_avg_TD_att']
del df['B_avg_TD_pct']
del df['R_avg_TD_pct']
del df['B_avg_TOTAL_STR_att']
del df['R_avg_TOTAL_STR_att']
del df['B_avg_opp_BODY_att']
del df['R_avg_opp_BODY_att']
del df['B_avg_opp_CLINCH_att']
del df['R_avg_opp_CLINCH_att']
del df['B_avg_opp_DISTANCE_att']
del df['R_avg_opp_DISTANCE_att']
del df['B_avg_opp_GROUND_att']
del df['R_avg_opp_GROUND_att']
del df['B_avg_opp_HEAD_att']
del df['R_avg_opp_HEAD_att']
del df['B_avg_opp_LEG_att']
del df['R_avg_opp_LEG_att']
del df['B_avg_opp_SIG_STR_att']
del df['R_avg_opp_SIG_STR_att']
del df['B_avg_opp_TD_att']
del df['R_avg_opp_TD_att']
del df['B_avg_opp_TD_pct']
del df['R_avg_opp_TD_pct']
del df['B_avg_opp_TOTAL_STR_att']
del df['R_avg_opp_TOTAL_STR_att']
del df['B_total_rounds_fought']
del df['R_total_rounds_fought']
del df['B_Weight_lbs']
del df['R_Weight_lbs']
del df['B_Height_cms']
del df['R_Height_cms']
del df['B_Reach_cms']
del df['R_Reach_cms']
del df['B_win_by_Submission']
del df['R_win_by_Submission']
del df['B_win_by_Decision_Split']
del df['R_win_by_Decision_Split']
del df['B_win_by_Decision_Majority']
del df['R_win_by_Decision_Majority']
del df['B_win_by_Decision_Unanimous']
del df['R_win_by_Decision_Unanimous']
del df['B_win_by_KO/TKO']
del df['R_win_by_KO/TKO']
del df['B_win_by_TKO_Doctor_Stoppage']
del df['R_win_by_TKO_Doctor_Stoppage']
del df['B_total_time_fought(seconds)']
del df['R_total_time_fought(seconds)']
#del df['B_avg_BODY_landed']
#del df['B_avg_CLINCH_landed']
#del df['B_avg_DISTANCE_landed']
#del df['B_avg_GROUND_landed']
#del df['B_avg_HEAD_landed']
#del df['B_avg_LEG_landed']
#del df['B_avg_SIG_STR_landed']
#del df['B_avg_TD_landed']
del df['B_avg_TOTAL_STR_landed']
del df['B_avg_opp_BODY_landed']
del df['B_avg_opp_CLINCH_landed']
del df['B_avg_opp_DISTANCE_landed']
del df['B_avg_opp_GROUND_landed']
del df['B_avg_opp_HEAD_landed']
del df['B_avg_opp_LEG_landed']
del df['B_avg_opp_SIG_STR_landed']
del df['B_avg_opp_TD_landed']
del df['B_avg_opp_TOTAL_STR_landed']
#del df['R_avg_BODY_landed']
#del df['R_avg_CLINCH_landed']
#del df['R_avg_DISTANCE_landed']
#del df['R_avg_GROUND_landed']
#del df['R_avg_HEAD_landed']
#del df['R_avg_LEG_landed']
#del df['R_avg_SIG_STR_landed']
#del df['R_avg_TD_landed']
#del df['R_avg_TOTAL_STR_landed']
del df['R_avg_opp_BODY_landed']
del df['R_avg_opp_CLINCH_landed']
del df['R_avg_opp_DISTANCE_landed']
del df['R_avg_opp_GROUND_landed']
del df['R_avg_opp_HEAD_landed']
del df['R_avg_opp_LEG_landed']
del df['R_avg_opp_SIG_STR_landed']
del df['R_avg_opp_TD_landed']
del df['R_avg_opp_TOTAL_STR_landed']

for i in df:
    if df[i].dtype == object:
        del df[i]
print(df.columns)
for i in df:
    if i != 'Winner':
        df.sort_values(i)

features = []
for i in df.columns:
    if i != 'Winner':
        features.append(i)
# Out:
# Index(['Winner', 'B_avg_BODY_landed', 'B_avg_CLINCH_landed',
#        'B_avg_DISTANCE_landed', 'B_avg_GROUND_landed', 'B_avg_HEAD_landed',
#        'B_avg_LEG_landed', 'B_avg_SIG_STR_landed', 'B_avg_TD_landed',
#        'R_avg_BODY_landed', 'R_avg_CLINCH_landed', 'R_avg_DISTANCE_landed',
#        'R_avg_GROUND_landed', 'R_avg_HEAD_landed', 'R_avg_LEG_landed',
#        'R_avg_SIG_STR_landed', 'R_avg_TD_landed', 'R_avg_TOTAL_STR_landed'],
#       dtype='object')

# %% [markdown]
# After determining which features I was most interested in, I decided to explore how these features correlated to each other. The strongest correlation, R_avg_SIG_STR_landed and R_avg_HEAD_landed, occurs because SIG_STR, or significant strike, includes strikes to the head.

# %%
ax = sns.heatmap(
    df.corr(), 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# There was an issue with preparing the data where when the two final datasets were assigned to X and Y, it appeared as if Y became longer by 2 values. Because of this I deleted those final two rows.

# %%
X = df.drop(df['Winner'])
Y = df['Winner']
Y = Y.drop(3151)
Y = Y.drop(3150)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 465)

# %% [markdown]
# Regressive models did not perform well with this dataset, as is evident in the performance of the K Nearest Neighbor Regressor, and the Decision Tree Regressor. This might be due to the fact that these values were categorical instead of continuous.

# %%
knn = KNeighborsRegressor(n_neighbors=10)
Y2 = Y.to_numpy()
knn.fit(X, Y)
score = cross_val_score(knn, X, Y, cv=10)
print(score)
print("Unweighted Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
# Out:
# [-0.19017792 -0.11344878 -0.13124069 -0.15234766 -0.12626921 -0.14195192
#  -0.09455652 -0.16796296 -0.17619048  0.        ]
# Unweighted Accuracy: -0.13 (+/- 0.10)

# %%
decision_tree = tree.DecisionTreeRegressor(max_depth=2)
decision_tree.fit(X,Y)
score = cross_val_score(decision_tree, X, Y, cv=5)
print(score)
print("Unweighted Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
# Out:
# [-0.08335415 -0.17167388 -0.14473121  0.14725064 -0.56960357]
# Unweighted Accuracy: -0.16 (+/- 0.46)

# %% [markdown]
# KNN Classifier performed significantly better than the Regressor. The performance is still significantly lacking. The model barely performs better than a coin flip. While on other datasets, this could be associated with overfitting, I tried multiple combinations of values and achieved similar results (more on the results later).

# %%
neighbors = KNeighborsClassifier(n_neighbors=5)
neighbors.fit(X,Y)
score = cross_val_score(neighbors, X, Y, cv=10)
print(score)
print("Unweighted Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
# Out:
# [0.53164557 0.5221519  0.56012658 0.57278481 0.53333333 0.57961783
#  0.57324841 0.60828025 0.65286624 0.66242038]
# Unweighted Accuracy: 0.58 (+/- 0.09)

# %% [markdown]
# The Random Forest Classifier and Decision Tree Classifiers did the best out of any models. This is due to the Decision Tree's strength handling categorical variables and a limited number of features

# %%
rfc = ensemble.RandomForestClassifier()
rfc.fit(X,Y)
print(cross_val_score(rfc, X, Y, cv=10))
# Out:
# C:\Users\mattb\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.49367089 0.52531646 0.54746835 0.53797468 0.4952381  0.50955414
#  0.59872611 0.6910828  0.77707006 0.75796178]

# %%
decision_tree = tree.DecisionTreeClassifier(
    criterion='entropy',
    max_features=1,
    max_depth=4,
    random_state = 500
)

decision_tree.fit(X,Y)
print(cross_val_score(decision_tree, X, Y, cv=10))

dot_data = tree.export_graphviz(
    decision_tree, out_file=None,
    #feature_names= features,
    class_names='Winner',
    filled=True
)
graph = pydotplus.graph_from_dot_data(dot_data)
graph.create_png()
Image(graph.create_png())
# Out:
# [0.58860759 0.5664557  0.53164557 0.53797468 0.57460317 0.63057325
#  0.6656051  0.64968153 0.65286624 0.67197452]

# %% [markdown]
# Here I've plotted AUC-ROC curves for my Classifiers. I'm interested in seeing, side by side, how these models perform in determining true positives.

# %%
# Instantiate the classfiers and make a list
classifiers = [KNeighborsClassifier(), 
               DecisionTreeClassifier(random_state=1234),
               RandomForestClassifier(random_state=1234)]

# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for cls in classifiers:
    model = cls.fit(X_train, y_train)
    yproba = model.predict_proba(X_test)[::,1]
    
    fpr, tpr, _ = roc_curve(y_test,  yproba)
    auc = roc_auc_score(y_test, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)

fig = plt.figure(figsize=(8,6))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()
# Out:
# C:\Users\mattb\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# The SVM doesn't show significant improvements over the other models. We still have Decision trees to see if they are the best model.

# %%
svm = SVC(kernel = 'linear')
svm.fit(X, Y)
score = cross_val_score(svm, X, Y, cv=5)
print(score)
print("Unweighted Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
# Out:
# [0.54285714 0.4952381  0.54603175 0.63968254 0.64069952]
# Unweighted Accuracy: 0.57 (+/- 0.12)

# %% [markdown]
# Conclusion: I would use the Decision Tree Classifier as my predictive model for determining fight winners. Would I bet on this model? No.

# %% [markdown]
# About the data: Is it possible to use the type of hits by a specific corner to either explain other data or predict future outcomes? The short answer is no. What my data ignores are the individual fighters and what they bring to the table. Maybe one fighter has less hits, but hits harder. Because I didn't consider fighters, force, or timing, it is hard to make those predictions.
